# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
import pandas
import IPython.display

# %% [markdown]
# ## estimating onsets in python

# %%
def getOnsetsEnv(sig,sr=44100):

    o_env = librosa.onset.onset_strength(sig, sr=sr)
    times = librosa.frames_to_time(np.arange(len(o_env)), sr=sr)
    onset_frames = librosa.onset.onset_detect(onset_envelope=o_env, sr=sr)

    D = np.abs(librosa.stft(sig,n_fft=4096))
    plt.figure()
    ax1 = plt.subplot(2, 1, 1)
    librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), hop_length=512, x_axis='time', y_axis='log')
    plt.title('Estimated from Onset Envelope')
    plt.subplot(2, 1, 2, sharex=ax1)
    plt.plot(times, o_env, label='Onset strength')
    plt.vlinesines(times[onset_frames], 0, o_env.max(), color='r', alpha=0.9, linestyle='--', label='Onsets')
    plt.axis('tight')
    plt.legend(frameon=True, framealpha=0.75)
    
    return onset_frames

# %%
def getOnsetsWrapper(filename):
    sig , sr = librosa.load(filename,mono=True,sr=None)
    
    # estimate onsets from an onset envelope
    onset_frames = getOnsetsEnv(sig,sr)
    print('Estimated onsets:')
    print(librosa.frames_to_time(onset_frames, sr=sr))

# %%
file = 'kingsLoop.wav'
getOnsetsWrapper(file)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-39499271b5a7> in <module>()
#       1 file = 'kingsLoop.wav'
# ----> 2 getOnsetsWrapper(file)
#
# <ipython-input-4-310af1e24e57> in getOnsetsWrapper(filename)
#       3
#       4     # estimate onsets from an onset envelope
# ----> 5     onset_frames = getOnsetsEnv(sig,sr)
#       6     print('Estimated onsets:')
#       7     print(librosa.frames_to_time(onset_frames, sr=sr))
#
# <ipython-input-3-d2e9d79073d4> in getOnsetsEnv(sig, sr)
#      12     plt.subplot(2, 1, 2, sharex=ax1)
#      13     plt.plot(times, o_env, label='Onset strength')
# ---> 14     plt.vlinesines(times[onset_frames], 0, o_env.max(), color='r', alpha=0.9, linestyle='--', label='Onsets')
#      15     plt.axis('tight')
#      16     plt.legend(frameon=True, framealpha=0.75)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'vlinesines'

# %%
file2 = 'avm.wav'
getOnsetsWrapper(file2)

# %%
file3 = 'mozartSeg.wav'
getOnsetsWrapper(file3)

# %%
file4 = 'chopinSeg.wav'
getOnsetsWrapper(file4)

# %% [markdown]
# ## import onset estimates from sonic visualiser

# %%
def readOnsetCSV(audiofilename,csvfilename):

    df = pandas.read_csv(csvfilename,header=None)
    times=df.loc[:,0]

    sig , sr = librosa.load(audiofilename,mono=True,sr=None)
    D = np.abs(librosa.stft(sig,n_fft=4096))
    plt.figure()
    ax1 = plt.subplot(2, 1, 1)
    librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), x_axis='time', y_axis='log')
    plt.title('Estimated from Sonic Visualiser')
    plt.subplot(2, 1, 2, sharex=ax1)
    plt.vlines(times, 0, 1, color='r', alpha=0.9, linestyle='--', label='Onsets')
    plt.axis('tight')
    plt.legend(frameon=True, framealpha=0.75)
    
    print('Estimated onsets:')
    print(times.tolist())

# %%
# df is data frames

# %%
readOnsetCSV('kingsLoop.wav','kingsLoopOnsets.csv')
# Out:
# Estimated onsets:
# [0.232199546, 0.417959184, 0.65015873, 0.882358277, 1.0681179140000001, 1.30031746, 1.4860770980000002, 1.7182766440000001, 1.904036281, 2.1362358280000002, 2.321995465, 2.554195011, 2.739954649, 2.972154195, 3.2043537410000003, 3.3901133789999998, 3.622312925, 3.808072562, 4.040272109, 4.226031746, 4.458231293, 4.64399093, 4.8761904760000006, 5.061950113, 5.29414966, 5.479909297000001, 5.712108843999999, 5.94430839, 6.130068027, 6.362267574, 6.548027211]

# %%
y, sr = librosa.load('kingsLoop.wav')
samp = np.zeros(len(y))
sampLoc=librosa.times_to_samples(times.values, sr=sr)
samp[sampLoc]=1
IPython.display.Audio(data=samp, rate=sr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-b9369c1bb911> in <module>()
#       1 y, sr = librosa.load('kingsLoop.wav')
#       2 samp = np.zeros(len(y))
# ----> 3 sampLoc=librosa.times_to_samples(times.values, sr=sr)
#       4 samp[sampLoc]=1
#       5 IPython.display.Audio(data=samp, rate=sr)
#
# AttributeError: module 'librosa' has no attribute 'times_to_samples'
