# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
import pandas
import IPython.display

# %% [markdown]
# ## KingsLoop

# %%
file = 'kingsLoop.wav'
sig , sr = librosa.load("kingsLoop.wav",mono=True,sr=None)
D = np.abs(librosa.stft(sig,n_fft=4096))
librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), x_axis='time', y_axis='log')
plt.title('Onest Estimates from kingsLoop.wav')
# Out:
# Text(0.5,1,'Onest Estimates from kingsLoop.wav')

# %%
sig , sr = librosa.load("kingsLoop.wav",mono=True,sr=None)
smooth_df = pandas.read_csv('kingsLoop_vamp_qm-vamp-plugins_qm-onsetdetector_smoothed_df.csv',header=None)
smooth_df = smoothed_df.values

qm-onsetdetector_onsets = pandas.read_csv('kingsLoop_vamp_qm-vamp-plugins_qm-onsetdetector_onsets.csv',header=None) 
qm-onsetdetector_onsets = onsetdetector.values

plt.figure()
plt.title('Loudness-related estimates for kingsLoop.wav')
D = np.abs(librosa.stft(sig1,n_fft=4096))
plt.figure()
librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), x_axis='time', y_axis='log',cmap='gray')
plt.hold
plt.plot(smooth_df[:,0],smooth_df[:,1],color = 'm')
plt.plot(qm-onsetdetector_onsets[:,0],qm-onsetdetector_onsets[:,1]*1000,color = 'g')
# Out:
#   File "<ipython-input-99-b7b250f6f782>", line 5
#     qm-onsetdetector_onsets = pandas.read_csv('kingsLoop_vamp_qm-vamp-plugins_qm-onsetdetector_onsets.csv',header=None)
#                                                                                                                         ^
# SyntaxError: can't assign to operator
