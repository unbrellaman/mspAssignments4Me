# %%
import matplotlib.pyplot as plt
import numpy as np
import aubio

# %%
filename='avmA.wav'
downsample = (1)
samplerate = (44100)
win_s = 1764 // downsample # fft size
hop_s = 441 // downsample # hop size
s = aubio.source(filename, samplerate, hop_s)
samplerate = s.samplerate
tolerance = 0.1

start_time = time()
pitch_o = aubio.pitch("yin", win_s, hop_s, samplerate) 
#pitch_o.set_unit("midi")
pitch_o.set_tolerance(0.1)

pitchesYIN = []
confidences = [] 
total_frames = 0
while True:
    samples, read = s()
    pitch = pitch_o(samples)[0]
    pitch = int(round(pitch))
    confidence = pitch_o.get_confidence()
    pitchesYIN += [pitch]
    confidences += [confidence]
    total_frames += read
    if read < hop_s:
         break        
stop_time = time()  
print('Calculating frequency from YIN:'),
print('%f Hz' % mean(pitchesYIN))
print('Time elapsed: %.3f s\n' % (stop_time - start_time))
fig, (ax1) = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(12, 8))
ax1.plot(np.asarray(pitchesYIN), color='blue')
plt.title('A-')
plt.ylabel('Freq (Hz)')
plt.xlabel('Frames')
# Out:
# Calculating frequency from YIN:
# 453.268966 Hz
# Time elapsed: 0.029 s
# Text(0.5,0,'Frames')

# %%
filename='avmA2.wav'
downsample = (1)
samplerate = (44100)
win_s = 1764 // downsample # fft size
hop_s = 441 // downsample # hop size
s = aubio.source(filename, samplerate, hop_s)
samplerate = s.samplerate
tolerance = 0.1

start_time = time()
pitch_o = aubio.pitch("yin", win_s, hop_s, samplerate) 
#pitch_o.set_unit("midi")
pitch_o.set_tolerance(0.1)

pitchesYIN = []
confidences = [] 
total_frames = 0
while True:
    samples, read = s()
    pitch = pitch_o(samples)[0]
    pitch = int(round(pitch))
    confidence = pitch_o.get_confidence()
    pitchesYIN += [pitch]
    confidences += [confidence]
    total_frames += read
    if read < hop_s:
         break        
stop_time = time()  
print('Calculating frequency from YIN:'),
print('%f Hz' % mean(pitchesYIN))
print('Time elapsed: %.3f s\n' % (stop_time - start_time))
fig, (ax1) = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(12, 8))
ax1.plot(np.asarray(pitchesYIN), color='blue')
plt.title('-a')
plt.ylabel('Freq (Hz)')
plt.xlabel('Frames')
# Out:
# Calculating frequency from YIN:
# 432.832402 Hz
# Time elapsed: 0.020 s
# Text(0.5,0,'Frames')

# %%
filename='avmI.wav'
downsample = (1)
samplerate = (44100)
win_s = 1764 // downsample # fft size
hop_s = 441 // downsample # hop size
s = aubio.source(filename, samplerate, hop_s)
samplerate = s.samplerate
tolerance = 0.1

start_time = time()
pitch_o = aubio.pitch("yin", win_s, hop_s, samplerate) 
#pitch_o.set_unit("midi")
pitch_o.set_tolerance(0.1)

pitchesYIN = []
confidences = [] 
total_frames = 0
while True:
    samples, read = s()
    pitch = pitch_o(samples)[0]
    pitch = int(round(pitch))
    confidence = pitch_o.get_confidence()
    pitchesYIN += [pitch]
    confidences += [confidence]
    total_frames += read
    if read < hop_s:
         break        
stop_time = time()  
print('Calculating frequency from YIN:'),
print('%f Hz' % mean(pitchesYIN))
print('Time elapsed: %.3f s\n' % (stop_time - start_time))
fig, (ax1) = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(12, 8))
ax1.plot(np.asarray(pitchesYIN), color='blue')
plt.title('-i-')
plt.ylabel('Freq (Hz)')
plt.xlabel('Frames')
# Out:
# Calculating frequency from YIN:
# 477.381818 Hz
# Time elapsed: 0.007 s
# Text(0.5,0,'Frames')

# %%
filename='avmMa.wav'
downsample = (1)
samplerate = (44100)
win_s = 1764 // downsample # fft size
hop_s = 441 // downsample # hop size
s = aubio.source(filename, samplerate, hop_s)
samplerate = s.samplerate
tolerance = 0.1

start_time = time()
pitch_o = aubio.pitch("yin", win_s, hop_s, samplerate) 
#pitch_o.set_unit("midi")
pitch_o.set_tolerance(0.1)

pitchesYIN = []
confidences = [] 
total_frames = 0
while True:
    samples, read = s()
    pitch = pitch_o(samples)[0]
    pitch = int(round(pitch))
    confidence = pitch_o.get_confidence()
    pitchesYIN += [pitch]
    confidences += [confidence]
    total_frames += read
    if read < hop_s:
         break        
stop_time = time()  
print('Calculating frequency from YIN:'),
print('%f Hz' % mean(pitchesYIN))
print('Time elapsed: %.3f s\n' % (stop_time - start_time))
fig, (ax1) = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(12, 8))
ax1.plot(np.asarray(pitchesYIN), color='blue')
plt.title('-a')
plt.ylabel('Freq (Hz)')
plt.xlabel('Frames')
# Out:
# Calculating frequency from YIN:
# 1683.185714 Hz
# Time elapsed: 0.009 s
# Text(0.5,0,'Frames')

# %%
# I do not understand why this above plot doesn't match the pdf.

# %%
filename='avmRi1.wav'
downsample = (1)
samplerate = (44100)
win_s = 1764 // downsample # fft size
hop_s = 441 // downsample # hop size
s = aubio.source(filename, samplerate, hop_s)
samplerate = s.samplerate
tolerance = 0.1

start_time = time()
pitch_o = aubio.pitch("yin", win_s, hop_s, samplerate) 
#pitch_o.set_unit("midi")
pitch_o.set_tolerance(0.1)

pitchesYIN = []
confidences = [] 
total_frames = 0
while True:
    samples, read = s()
    pitch = pitch_o(samples)[0]
    pitch = int(round(pitch))
    confidence = pitch_o.get_confidence()
    pitchesYIN += [pitch]
    confidences += [confidence]
    total_frames += read
    if read < hop_s:
         break        
stop_time = time()  
print('Calculating frequency from YIN:'),
print('%f Hz' % mean(pitchesYIN))
print('Time elapsed: %.3f s\n' % (stop_time - start_time))
fig, (ax1) = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(12, 8))
ax1.plot(np.asarray(pitchesYIN), color='blue')
plt.title('-ri-')
plt.ylabel('Freq (Hz)')
plt.xlabel('Frames')
# Out:
# Calculating frequency from YIN:
# 554.484043 Hz
# Time elapsed: 0.030 s
# Text(0.5,0,'Frames')

# %%
filename='avmVe.wav'
downsample = (1)
samplerate = (44100)
win_s = 1764 // downsample # fft size
hop_s = 441 // downsample # hop size
s = aubio.source(filename, samplerate, hop_s)
samplerate = s.samplerate
tolerance = 0.1

start_time = time()
pitch_o = aubio.pitch("yin", win_s, hop_s, samplerate) 
#pitch_o.set_unit("midi")
pitch_o.set_tolerance(0.1)

pitchesYIN = []
confidences = [] 
total_frames = 0
while True:
    samples, read = s()
    pitch = pitch_o(samples)[0]
    pitch = int(round(pitch))
    confidence = pitch_o.get_confidence()
    pitchesYIN += [pitch]
    confidences += [confidence]
    total_frames += read
    if read < hop_s:
         break        
stop_time = time()  
print('Calculating frequency from YIN:'),
print('%f Hz' % mean(pitchesYIN))
print('Time elapsed: %.3f s\n' % (stop_time - start_time))
fig, (ax1) = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(12, 8))
ax1.plot(np.asarray(pitchesYIN), color='blue')
plt.title('-ve')
plt.ylabel('Freq (Hz)')
plt.xlabel('Frames')
# Out:
# Calculating frequency from YIN:
# 402.074074 Hz
# Time elapsed: 0.008 s
# Text(0.5,0,'Frames')

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')
